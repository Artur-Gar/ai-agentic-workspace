# %% [markdown]
# # Demonstration Note
# For this demonstration, I used the open Chinook database available at the following link:
# [https://docs.yugabyte.com/preview/sample-data/chinook/](https://docs.yugabyte.com/preview/sample-data/chinook/)

# %%
from main import AgenticWorkspace

workspace = AgenticWorkspace()

# %%
demo_tasks = [
    "What tables are available in the database?",
    "Query the database for all customers and create a bar chart with their number per country, sorted in descending order",
    "Generated same chart as in previous request, but , excluding the United States, while keeping all other countries."
]

# %%
# 1st task
task_number = 0
print(f"\n{'='*50}")
print(f"Task {task_number}: {demo_tasks[task_number]}")
print('='*50)
        
result = workspace.process_task(demo_tasks[task_number])
     
print(f"Agent Plan: {result['agent_plan']}")
print(f"Final Output: {result['final_output']}")
print(f"Success: {result['success']}")
# Out:
# ...
# Task 0: What tables are available in the database?
# ...
#
#  Processing task: What tables are available in the database?
# [ROUTER] - Planning agent sequence...
# [ROUTER] - Planned sequence: ['sql_agent', 'summary_agent']
# [DECIDER] - Next agent: sql_agent
# [SQL AGENT] - Running SQL query...
# [DECIDER] - Next agent: summary_agent
# [SUMMARY AGENT] - Generating final report...
# Agent Plan: ['sql_agent', 'summary_agent']
# Final Output: Summary:
#
# Database Query Results: The available tables in the database are:
#
# 1. album
# 2. artist
# 3. customer
# 4. employee
# 5. genre
# 6. invoice
# 7. invoiceline
# 8. mediatype
# 9. playlist
# 10. playlisttrack
# 11. track...
# Success: True

# %%
# 2nd task
task_number = 1
print(f"\n{'='*50}")
print(f"Task {task_number}: {demo_tasks[task_number]}")
print('='*50)
        
result = workspace.process_task(demo_tasks[task_number])
     
print(f"Agent Plan: {result['agent_plan']}")
print(f"Final Output: {result['final_output']}")
print(f"Success: {result['success']}")
# Out:
# ...
# Task 1: Query the database for all customers and create a bar chart with their number per country, sorted in descending order
# ...
#
#  Processing task: Query the database for all customers and create a bar chart with their number per country, sorted in descending order
# [ROUTER] - Planning agent sequence...
# [ROUTER] - Planned sequence: ['sql_agent', 'visualization_agent', 'summary_agent']
# [DECIDER] - Next agent: sql_agent
# [SQL AGENT] - Running SQL query...
# [DECIDER] - Next agent: visualization_agent
# [VISUALIZATION AGENT]  Creating visualizations...
# [DECIDER] - Next agent: summary_agent
# [SUMMARY AGENT] - Generating final report...
# Agent Plan: ['sql_agent', 'visualization_agent', 'summary_agent']
# Final Output: Summary:
#
# Database Query Results: Here are the number of customers per country, sorted in descending order:
#
# 1. USA: 13
# 2. Canada: 8
# 3. Brazil: 5
# 4. France: 5
# 5. Germany: 4
# 6. United Kingdom: 3
# 7. Czech Republic: 2
# 8. India: 2
# 9. Portugal: 2
# ...

# %%
# 3rd task
task_number = 2
print(f"\n{'='*50}")
print(f"Task {task_number}: {demo_tasks[task_number]}")
print('='*50)
        
result = workspace.process_task(demo_tasks[task_number])
     
print(f"Agent Plan: {result['agent_plan']}")
print(f"Final Output: {result['final_output']}")
print(f"Success: {result['success']}")
# Out:
# ...
# Task 2: Generated same chart as in previous request, but , excluding the United States, while keeping all other countries.
# ...
#
#  Processing task: Generated same chart as in previous request, but , excluding the United States, while keeping all other countries.
# [ROUTER] - Planning agent sequence...
# [ROUTER] - Planned sequence: ['sql_agent', 'visualization_agent', 'summary_agent']
# [DECIDER] - Next agent: sql_agent
# [SQL AGENT] - Running SQL query...
# [DECIDER] - Next agent: visualization_agent
# [VISUALIZATION AGENT]  Creating visualizations...
# [DECIDER] - Next agent: summary_agent
# [SUMMARY AGENT] - Generating final report...
# Agent Plan: ['sql_agent', 'visualization_agent', 'summary_agent']
# Final Output: Summary:
#
# Database Query Results: Here are the number of customers per country, excluding the United States, sorted in descending order:
#
# 1. Canada: 8
# 2. Brazil: 5
# 3. France: 5
# 4. Germany: 4
# 5. United Kingdom: 3
# 6. Czech Republic: 2
# 7. India: 2
# ...

# %% [markdown]
# ## Memory

# %%
workspace.memory
# Out:
# [{'user': 'What tables are available in the database?',
#   'assistant': 'Summary:\n\nDatabase Query Results: The available tables in the database are: \n\n1. album\n2. artist\n3. customer\n4. employee\n5. genre\n6. invoice\n7. invoiceline\n8. mediatype\n9. playlist\n10. playlisttrack\n11. track...'},
#  {'user': 'Query the database for all customers and create a bar chart with their number per country, sorted in descending order',
#   'assistant': 'Summary:\n\nDatabase Query Results: Here are the number of customers per country, sorted in descending order:\n\n1. USA: 13\n2. Canada: 8\n3. Brazil: 5\n4. France: 5\n5. Germany: 4\n6. United Kingdom: 3\n7. Czech Republic: 2\n8. India: 2\n9. Portugal: 2\n10. Norway: 1...\n\nVisualizations Results: The bar chart showing the number of customers per country, s...'},
#  {'user': 'Generated same chart as in previous request, but , excluding the United States, while keeping all other countries.',
# ...

# %% [markdown]
# ## LangGraph Workflow

# %%
workspace.workflow
