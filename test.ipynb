# %%
from agents.sql_agent import SQLAgent
from agents.visualization_agent import VisualizationAgent
from utils.orchestrator import Orchestrator

# %%
# Create orchestrator
orchestrator = Orchestrator()

# Initialize agents with orchestrator
sql_agent = SQLAgent(orchestrator)
viz_agent = VisualizationAgent(orchestrator)

# Step 1: Run SQL query (plain text output)
text_output = sql_agent.run_whole_pipeline("Plot me the number of customers by country, sorted in descending order")

# %%
text_output
# Out:
# {'output': 'The query results show the number of customers by country, sorted in descending order:\n\n1. USA: 13 customers\n2. Canada: 8 customers\n3. Brazil: 5 customers\n4. France: 5 customers\n5. Germany: 4 customers\n6. United Kingdom: 3 customers\n7. Czech Republic: 2 customers\n8. Portugal: 2 customers\n9. India: 2 customers\n10. Norway: 1 customer\n\nand so on.'}

# %%
orchestrator.current_dataframe
# Out:
#           Country  Number of Customers
# 0             USA                   13
# 1          Canada                    8
# 2          Brazil                    5
# 3          France                    5
# 4         Germany                    4
# 5  United Kingdom                    3
# 6  Czech Republic                    2
# 7        Portugal                    2
# 8           India                    2
# 9          Norway                    1

# %%
# Step 3: Visualize it
text = (
    "Plot me the number of customers by country, sorted in descending order"
)
response = viz_agent.visualize(text)
print(response)
# Out:
# c:\Programming\venvs\agents\Lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:283: UserWarning: Received additional kwargs {'handle_parsing_errors': True} which are no longer supported.
#   warnings.warn(
# ###################### result of visualisation:
# ...

# %%
response
# Out:
# {'output': "The plot of the number of customers by country, sorted in descending order, has been created.\n\n✅ Auto-saved plot at: plots\\auto_saved_2025_10_24_12_32_31.png\n\nGenerated Code:\ndf.groupby('Country')['Number of Customers'].sum().sort_values(ascending=False).plot(kind='bar')"}
