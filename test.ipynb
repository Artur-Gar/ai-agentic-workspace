# %%
from agents.sql_agent import SQLAgent
from agents.visualization_agent import VisualizationAgent

# %%
sql_agent = SQLAgent()
viz_agent = VisualizationAgent()

# Step 1: Run SQL query (plain text output)
text_output = sql_agent.query("Plot me the number of customers by country, sorted in descending order")

# %%
text_output
# Out:
# 'The number of customers by country, sorted in descending order, are as follows:\n1. USA: 13 customers\n2. Canada: 8 customers\n3. Brazil: 5 customers\n4. France: 5 customers\n5. Germany: 4 customers\n6. United Kingdom: 3 customers\n7. Czech Republic: 2 customers\n8. Portugal: 2 customers\n9. India: 2 customers\n10. Norway: 1 customer'

# %%
# Step 3: Visualize it
text = "Plot a bar chart of CustomerCount by Country, " + text_output

response = viz_agent.run_whole_pipeline(text)
print(response)
# Out:
# The bar chart of CustomerCount by Country has been plotted.
#
# Generated Code:
# plt.bar(df_sorted['Country'], df_sorted['CustomerCount'])

# %%
response
# Out:
# "The bar chart of CustomerCount by Country has been plotted.\n\nGenerated Code:\nplt.bar(df_sorted['Country'], df_sorted['CustomerCount'])"
